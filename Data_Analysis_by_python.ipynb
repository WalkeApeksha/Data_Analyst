# %% [markdown]
# <a href="https://colab.research.google.com/github/WalkeApeksha/Data_Analyst/blob/main/Data_Analysis_by_python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt # visualizing data
# %matplotlib inline
import seaborn as sns

# %%
df=pd.read_csv('Sales_Data.csv',encoding='unicode_escape')

# %%
df.shape
# Out:
# (11257, 13)

# %%
df.head(5)
# Out:
#      User_ID Cust_name Product_ID   Age Age Group  Gender           State  \
# 0  1002903.0      Anvi  P00125942  27.0     26-35  Female     Maharashtra
# 1  1000732.0    Shanta  P00110942  34.0     26-35  Female  Andhra Pradesh
# 2  1001990.0   Sheetal  P00118542  16.0      0-17  Female   Uttar Pradesh
# 3  1001425.0  Virendra  P00237842  16.0      0-17       M       Karnataka
# 4  1000588.0    Vishal  P00057942  28.0     26-35       M         Gujarat
#
#       Zone  Zipcode       Profession Product_Category  Orders   Amount
# 0     West      NaN       Healthcare          Sports      4.0  20500.0
# 1    South      NaN             Govt          Sports      2.0  25360.0
# 2  Central      NaN       Automobile           Health     4.0  29350.0
# 3    South      NaN     Construction         Clothing     6.0  23500.0
# 4     West      NaN  Food Processing      Electronics     4.0  23870.0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11257 entries, 0 to 11256
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   User_ID           11245 non-null  float64
#  1   Cust_name         11245 non-null  object
#  2   Product_ID        11245 non-null  object
#  3   Age               11245 non-null  float64
#  4   Age Group         11245 non-null  object
#  5   Gender            11245 non-null  object
#  6   State             11245 non-null  object
#  7   Zone              11245 non-null  object
#  8   Zipcode           0 non-null      float64
#  9   Profession        11245 non-null  object
#  10  Product_Category  11245 non-null  object
#  11  Orders            11245 non-null  float64
#  12  Amount            11245 non-null  float64
# dtypes: float64(5), object(8)
# memory usage: 1.1+ MB

# %%
df.drop(['Zipcode'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['User_ID', 'Cust_name', 'Product_ID', 'Age', 'Age Group', 'Gender',
#        'State', 'Zone', 'Profession', 'Product_Category', 'Orders', 'Amount'],
#       dtype='object')

# %%
pd.isnull(df).sum()
# Out:
# User_ID             12
# Cust_name           12
# Product_ID          12
# Age                 12
# Age Group           12
# Gender              12
# State               12
# Zone                12
# Profession          12
# Product_Category    12
# Orders              12
# Amount              12
# dtype: int64

# %%
df.dropna(how='all',inplace=True)

# %%
df.shape
# Out:
# (11245, 12)

# %%
df['Gender']=df['Gender'].replace('M','Male')

# %%
df.head(15)
# Out:
#       User_ID Cust_name Product_ID   Age Age Group  Gender             State  \
# 0   1002903.0      Anvi  P00125942  27.0     26-35  Female       Maharashtra
# 1   1000732.0    Shanta  P00110942  34.0     26-35  Female    Andhra Pradesh
# 2   1001990.0   Sheetal  P00118542  16.0      0-17  Female     Uttar Pradesh
# 3   1001425.0  Virendra  P00237842  16.0      0-17    Male         Karnataka
# 4   1000588.0    Vishal  P00057942  28.0     26-35    Male           Gujarat
# 5   1000588.0    Suuraj  P00057942  28.0     26-35    Male  Himachal Pradesh
# 6   1001132.0     Sejal  P00018042  25.0     18-25  Female     Uttar Pradesh
# 7   1002092.0  Shivangi  P00273442  61.0       55+  Female       Maharashtra
# 8   1003224.0    Kushal  P00205642  35.0     26-35    Male     Uttar Pradesh
# 10  1003650.0     Meena  P00031142  26.0     26-35  Female    Andhra Pradesh
# 11  1003829.0     Harsh  P00200842  34.0     26-35    Male             Delhi
# 12  1000214.0      Raji  P00119142  20.0     18-25  Female    Andhra Pradesh
# 13  1004035.0     Shiva  P00080342  20.0     18-25  Female    Andhra Pradesh
# 14  1001680.0   Vasudev  P00324942  26.0     26-35    Male    Andhra Pradesh
# 15  1003858.0  Ravinath  P00293742  46.0     46-50    Male    Madhya Pradesh
#
#         Zone       Profession Product_Category  Orders   Amount
# 0       West       Healthcare          Sports      4.0  20500.0
# 1      South             Govt          Sports      2.0  25360.0
# 2    Central       Automobile           Health     4.0  29350.0
# 3      South     Construction         Clothing     6.0  23500.0
# 4       West  Food Processing      Electronics     4.0  23870.0
# 5   Northern  Food Processing      Electronics     3.0  23860.0
# 6    Central           Lawyer           Health     2.0  23841.0
# 7       West        IT Sector           Health     3.0  26000.0
# 8    Central             Govt           Beauty     4.0  23809.0
# 10     South            Media      Electronics     4.0  29000.0
# 11   Central          Banking           Health     2.0  23770.0
# 12     South           Retail      Electronics     3.0  23752.0
# 13     South        IT Sector           Health     5.0  23730.0
# 14     South       Automobile      Electronics     2.0  23718.0
# 15   Central      Hospitality         Clothing     1.0  25000.0

# %%
df[df['Gender']=='Male']
# Out:
#          User_ID    Cust_name Product_ID   Age Age Group Gender  \
# 3      1001425.0     Virendra  P00237842  16.0      0-17   Male
# 4      1000588.0       Vishal  P00057942  28.0     26-35   Male
# 5      1000588.0       Suuraj  P00057942  28.0     26-35   Male
# 8      1003224.0       Kushal  P00205642  35.0     26-35   Male
# 11     1003829.0        Harsh  P00200842  34.0     26-35   Male
# ...          ...          ...        ...   ...       ...    ...
# 11249  1005446.0      Sheetal  P00297742  53.0     51-55   Male
# 11250  1005446.0      Sheetal  P00297742  53.0     51-55   Male
# 11252  1000695.0      Manning  P00296942  19.0     18-25   Male
# 11253  1004089.0  Reichenbach  P00171342  33.0     26-35   Male
# 11255  1004023.0       Noonan  P00059442  37.0     36-45   Male
#
#                   State      Zone       Profession Product_Category  Orders  \
# 3             Karnataka     South     Construction         Clothing     6.0
# 4               Gujarat      West  Food Processing      Electronics     4.0
# 5      Himachal Pradesh  Northern  Food Processing      Electronics     3.0
# 8         Uttar Pradesh   Central             Govt           Beauty     4.0
# 11                Delhi   Central          Banking           Health     2.0
# ...                 ...       ...              ...              ...     ...
# 11249           Gujarat      West       Healthcare           Health     3.0
# 11250    Madhya Pradesh   Central       Healthcare           Health     2.0
# 11252       Maharashtra      West         Chemical           Health     1.0
# 11253           Haryana  Northern       Healthcare           Health     5.0
# 11255         Karnataka     South      Agriculture         Clothing     4.0
#
#         Amount
# 3      23500.0
# 4      23870.0
# 5      23860.0
# 8      23809.0
# 11     23770.0
# ...        ...
# 11249    382.0
# 11250    382.0
# 11252    370.0
# 11253    367.0
# 11255    206.0
#
# [3408 rows x 12 columns]

# %%
df.describe()
# Out:
#             User_ID           Age        Orders        Amount
# count  1.124500e+04  11245.000000  11245.000000  11245.000000
# mean   1.003004e+06     35.415651      3.500311   9461.934237
# std    1.716207e+03     12.756369      1.713706   5234.426634
# min    1.000001e+06     12.000000      1.000000    188.000000
# 25%    1.001492e+06     27.000000      2.000000   5443.000000
# 50%    1.003065e+06     33.000000      4.000000   8109.000000
# 75%    1.004429e+06     43.000000      5.000000  12683.000000
# max    1.006040e+06     92.000000      6.000000  29350.000000

# %%
df[['Age','Orders','Amount']].describe()
# Out:
#                 Age        Orders        Amount
# count  11245.000000  11245.000000  11245.000000
# mean      35.415651      3.500311   9461.934237
# std       12.756369      1.713706   5234.426634
# min       12.000000      1.000000    188.000000
# 25%       27.000000      2.000000   5443.000000
# 50%       33.000000      4.000000   8109.000000
# 75%       43.000000      5.000000  12683.000000
# max       92.000000      6.000000  29350.000000

# %%
ax=sns.countplot(x='Gender', data = df)
for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
ax = sns.countplot(x = 'Gender', data = df)

# %%
for bars in ax.containers:
    ax.bar_label(bars)
    ax.set_title('Gender Distribution', fontsize=24)   # Chart Title
    ax.set_xlabel('Gender', fontsize=24)               # X - Axis Label
    ax.set_ylabel('Count', fontsize=24)                # Y - Axis Label
    ax.tick_params(axis='both', labelsize=16)          # Axis Parameters
plt.show()

# %%
gender_counts = df['Gender'].value_counts()
print(gender_counts)
# Out:
# Gender
# Female    7837
# Male      3408
# Name: count, dtype: int64

# %%
gender_counts=df['Gender'].value_counts()
plt.pie(gender_counts,labels=gender_counts.index,autopct='%1.2f%%',startangle=90)
plt.title('Gender Distribution')
plt.show()

# %%
plt.title('Gender Distribution', fontsize=14)
plt.show()

# %%
df.groupby('Gender', as_index=False)['Amount'].sum()
# Out:
#    Gender       Amount
# 0  Female  74461610.49
# 1    Male  31937840.00

# %%
Gen_Wise_Sales=df.groupby('Gender',as_index=False)['Amount'].sum().sort_values(by='Amount',ascending=False)
print(Gen_Wise_Sales)
# Out:
#    Gender       Amount
# 0  Female  74461610.49
# 1    Male  31937840.00

# %%
Gen_Wise_Sales = df.groupby('Gender', as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

# %%
ax=sns.barplot(x='Gender',y='Amount',data=Gen_Wise_Sales)

# %%
ax = sns.barplot(x='Gender', y='Amount', data=Gen_Wise_Sales)

# Step 3: Add data labels on top of bars
for bar in ax.containers:
    ax.bar_label(bar, fmt='%.0f', fontsize=16, color='red')  # Show counts as whole numbers

# Step 4: Add titles
plt.title('Gender-wise Total Sales Amount', fontsize=14)
plt.show()

# %%
ax = sns.countplot(data = df, x = 'Age Group')

for bars in ax.containers:         #Show Data labels
    ax.bar_label(bars)
plt.show()

# %%
age_group_counts=df['Age Group'].value_counts().sort_values(ascending=False)

#Step 2 - Use Ordered categories for sorting in countplot
sns_order=age_group_counts.index

#Age Group wise Transactions Count in Bar Chart
ax = sns.countplot(data = df, x = 'Age Group', order=sns_order)

for bars in ax.containers:         #Show Data labels
    ax.bar_label(bars)
plt.show()

# %%
ax = sns.countplot(data = df, x = 'Age Group', hue = 'Gender')

for bars in ax.containers:
    ax.bar_label(bars)
plt.show()

# %%
sales_age = df.groupby(['Age Group'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False)

sns.barplot(x = 'Age Group',y= 'Amount' ,data = sales_age)

plt.show()

# %%
order_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(5)
print(order_state)
# Out:
#              State  Orders
# 14   Uttar Pradesh  6669.0
# 10     Maharashtra  5328.0
# 7        Karnataka  4506.0
# 2            Delhi  3893.0
# 9   Madhya Pradesh  3217.0

# %%
order_state = df.groupby(['State'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(5)

#sns.set(rc={'figure.figsize':(15,5)})
ax = sns.barplot(data = order_state, x = 'State',y= 'Orders')

for bars in ax.containers:
    ax.bar_label(bars)

plt.show()

# %%
sales_state = df.groupby(['State'], as_index=False)['Amount'].sum().sort_values(by='Amount', ascending=False).head(5)

sns.set(rc={'figure.figsize':(15,5)})
sns.barplot(data = sales_state, x = 'State',y= 'Amount')
plt.show()

# %%
sales_state = df.groupby(['Product_ID'], as_index=False)['Orders'].sum().sort_values(by='Orders', ascending=False).head(10)

sns.set(rc={'figure.figsize':(20,5)})
sns.barplot(data = sales_state, x = 'Product_ID',y= 'Orders')
plt.show()

# %%
import seaborn as sns
sns.barplot(x=[1,2,3], y=[4,5,6])
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt
plt.bar([1,2,3],[4,5,6])
plt.show()
